# %% [markdown]
# <a href="https://colab.research.google.com/github/habtamuadargaso/Python-for-Data-Science-/blob/main/Python%20%20For%20%20Data%20science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # oct 10/31/2022
# pandas library

# %%
import pandas as pd

# %%
# creating DataFram using the list 
# List of String
a = ['Python', 'Pandas','DataFrame','Dict','tuples' ]

# Calling DataFrame contructor on list
info = pd.DataFrame(a) 
info
# Out:
#            0
# 0     Python
# 1     Pandas
# 2  DataFrame
# 3       Dict
# 4     tuples

# %%
# Creating DataFrame from dict of ndarrays:
info = {'ID':[101,102,103], 'Department':['B.Sc','B.Tech','M.Tech'],'Description':['Degree','Masters','Ph.d']}
info = pd.DataFrame(info)
info
# Out:
#     ID Department Description
# 0  101       B.Sc      Degree
# 1  102     B.Tech     Masters
# 2  103     M.Tech        Ph.d

# %%
List = ['habtamu','Dargaso','Abera','Atnafu'] 
list_df = pd.DataFrame(List)
list_df
# Out:
#          0
# 0  habtamu
# 1  Dargaso
# 2    Abera
# 3   Atnafu

# %%
# Categorical data in pandas 
# Catagorical variable is generally used to take a limited and usually fixed number of possible values.

# %%
import numpy as np

# %%
# How to Extract  
info = {'x':0., 'y':1., 'z':2.}
a = pd.Series(info)
a
# Out:
# x    0.0
# y    1.0
# z    2.0
# dtype: float64

# %%
# importing the pandas as pd 
import pandas as pd
info =pd.DataFrame()
print(info)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# importing the pandas library 
import pandas as pd

# %%
# Add a new column to an existing DataFrame object
info = {'one': pd.Series([1,2,3,4,5], index = ['a', 'b','c','d','e']), 
        'two':pd.Series([1,2,3,4,5], index = ['a', 'b','c','d','e'])}
info = pd.DataFrame(info)      
info
# Out:
#    one  two
# a    1    1
# b    2    2
# c    3    3
# d    4    4
# e    5    5

# %%
info['three'] = pd.Series([20,40,60],index=['a','b','c'])
info
# Out:
#    one  two  three
# a    1    1   20.0
# b    2    2   40.0
# c    3    3   60.0
# d    4    4    NaN
# e    5    5    NaN

# %%
info['Four'] = info['one'] + info['three']
info
# Out:
#    one  two  three  Four
# a    1    1   20.0  21.0
# b    2    2   40.0  42.0
# c    3    3   60.0  63.0
# d    4    4    NaN   NaN
# e    5    5    NaN   NaN

# %%
# How to iterate over rows in pandas DataFram

# list of dicts  
input_df = [{'name':'Habtamu', 'age':10},
            {'name': 'Dargaso', 'age':11},
            {'name':'Atmafu','age':12}]
df = pd.DataFrame(input_df)      
df
# Out:
#       name  age
# 0  Habtamu   10
# 1  Dargaso   11
# 2   Atmafu   12

# %%
# how to iterated over the row the index  iterrow
for index, name in df.iterrows():
  print(name['name'])
# Out:
# Habtamu
# Dargaso
# Atmafu

# %%
# How to ready data using pandas library 
import pandas as pd
import numpy as np

# %%
# Read data from the url site 
url = "https://www.shadowbounce.com/data/student-performance.csv"

# %%
student_df = pd.read_csv(url)
student_df.head()
# Out:
#    gender income level        parental edu         lunch test prep course  \
# 0  female      group B   bachelor's degree      standard             none
# 1  female      group C        some college      standard        completed
# 2  female      group B     master's degree      standard             none
# 3    male      group A  associate's degree  free/reduced             none
# 4    male      group C        some college      standard             none
#
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
student_df = pd.read_csv(url)
student_df
# Out:
#      gender income level        parental edu         lunch test prep course  \
# 0    female      group B   bachelor's degree      standard             none
# 1    female      group C        some college      standard        completed
# 2    female      group B     master's degree      standard             none
# 3      male      group A  associate's degree  free/reduced             none
# 4      male      group C        some college      standard             none
# ..      ...          ...                 ...           ...              ...
# 995  female      group E     master's degree      standard        completed
# 996    male      group C         high school  free/reduced             none
# 997  female      group C         high school  free/reduced        completed
# 998  female      group D        some college      standard        completed
# 999  female      group D        some college  free/reduced             none
#
#      math score  reading score  writing score
# ...

# %%
# print the shape of 
print("Shape: ", student_df.shape)
# Out:
# Shape:  (1000, 8)

# %%
# print about the row number
print("row number",student_df.shape[0])

print("column number",student_df.shape[1])
# Out:
# row number 1000
# column number 8

# %%
# print the last 5 element of row info ()
student_df.tail()
# Out:
#      gender income level     parental edu         lunch test prep course  \
# 995  female      group E  master's degree      standard        completed
# 996    male      group C      high school  free/reduced             none
# 997  female      group C      high school  free/reduced        completed
# 998  female      group D     some college      standard        completed
# 999  female      group D     some college  free/reduced             none
#
#      math score  reading score  writing score
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
#Random number print out 
student_df.sample(5)
# Out:
#      gender income level        parental edu         lunch test prep course  \
# 526    male      group C    some high school  free/reduced        completed
# 258  female      group B        some college      standard             none
# 92     male      group C         high school      standard             none
# 5    female      group B  associate's degree      standard             none
# 852  female      group E        some college      standard             none
#
#      math score  reading score  writing score
# 526          56             61             60
# 258          70             75             78
# 92           71             79             71
# 5            71             83             78
# 852          87             85             93
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
# get to the columns of DF 
all_colums = student_df.columns
all_colums
# Out:
# Index(['gender', 'income level', 'parental edu', 'lunch', 'test prep course',
#        'math score', 'reading score', 'writing score'],
#       dtype='object')

# %%
# let get one signle column called math score  
math_score_df = student_df['math score']
math_score_df
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
print(type(math_score_df))
# Out:
# <class 'pandas.core.series.Series'>

# %%
math_score_df
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
 # To check the index 
 
print("\n Indices:" , student_df.index)
# Out:
#  Indices: RangeIndex(start=0, stop=1000, step=1)

# %%
# Get a list and a number of unqine value in a series 
print(sorted(math_score_df))
# Out:
# [0, 8, 18, 19, 22, 23, 24, 26, 27, 27, 28, 29, 29, 29, 30, 30, 32, 32, 32, 33, 34, 34, 35, 35, 35, 35, 35, 36, 36, 37, 37, 37, 37, 38, 38, 38, 39, 39, 39, 39, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 41, 41, 41, 41, 41, 41, 42, 42, 42, 42, 42, 42, 43, 43, 43, 43, 43, 44, 44, 44, 44, 44, 44, 44, 44, 44, 45, 45, 45, 45, 45, 45, 45, 45, 45, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 56, 56, 56, 56, 56, 56, 56, 56, 56, 57, 57,
# ...

# %%
print(math_score_df.nunique())
# Out:
# 81

# %%
# read the row 
student_df.iloc[3]
# Out:
# gender                            male
# income level                   group A
# parental edu        associate's degree
# lunch                     free/reduced
# test prep course                  none
# math score                          47
# reading score                       57
# writing score                       44
# Name: 3, dtype: object

# %%
student_df.isna()
# Out:
#      gender  income level  parental edu  lunch  test prep course  math score  \
# 0     False         False         False  False             False       False
# 1     False         False         False  False             False       False
# 2     False         False         False  False             False       False
# 3     False         False         False  False             False       False
# 4     False         False         False  False             False       False
# ..      ...           ...           ...    ...               ...         ...
# 995   False         False         False  False             False       False
# 996   False         False         False  False             False       False
# 997   False         False         False  False             False       False
# 998   False         False         False  False             False       False
# 999   False         False         False  False             False       False
#
#      reading score  writing score
# ...

# %%
# Get infomation 
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            1000 non-null   object
#  1   income level      1000 non-null   object
#  2   parental edu      1000 non-null   object
#  3   lunch             1000 non-null   object
#  4   test prep course  1000 non-null   object
#  5   math score        1000 non-null   int64
#  6   reading score     1000 non-null   int64
#  7   writing score     1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
math_score_df.head()
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# Name: math score, dtype: int64

# %%
# print the row 5 
one_row = student_df.iloc[5]
one_row
# Out:
# gender                          female
# income level                   group B
# parental edu        associate's degree
# lunch                         standard
# test prep course                  none
# math score                          71
# reading score                       83
# writing score                       78
# Name: 5, dtype: object

# %%
# only to print the first row 5 
student_df.head()
# Out:
#    gender income level        parental edu         lunch test prep course  \
# 0  female      group B   bachelor's degree      standard             none
# 1  female      group C        some college      standard        completed
# 2  female      group B     master's degree      standard             none
# 3    male      group A  associate's degree  free/reduced             none
# 4    male      group C        some college      standard             none
#
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
# To check the index 
one_row.index
# Out:
# Index(['gender', 'income level', 'parental edu', 'lunch', 'test prep course',
#        'math score', 'reading score', 'writing score'],
#       dtype='object')

# %%
# look if we have any missing row and column 
student_df.isna()
# Out:
#      gender  income level  parental edu  lunch  test prep course  math score  \
# 0     False         False         False  False             False       False
# 1     False         False         False  False             False       False
# 2     False         False         False  False             False       False
# 3     False         False         False  False             False       False
# 4     False         False         False  False             False       False
# ..      ...           ...           ...    ...               ...         ...
# 995   False         False         False  False             False       False
# 996   False         False         False  False             False       False
# 997   False         False         False  False             False       False
# 998   False         False         False  False             False       False
# 999   False         False         False  False             False       False
#
#      reading score  writing score
# ...

# %%
# To number of row or column that are missed 
student_df.isna().sum()
# Out:
# gender              0
# income level        0
# parental edu        0
# lunch               0
# test prep course    0
# math score          0
# reading score       0
# writing score       0
# dtype: int64

# %%
writing_score_df = student_df['writing score']
writing_score_df
# Out:
# 0      74
# 1      88
# 2      93
# 3      44
# 4      75
#        ..
# 995    95
# 996    55
# 997    65
# 998    77
# 999    86
# Name: writing score, Length: 1000, dtype: int64

# %%
student_df
# Out:
#      gender income level        parental edu         lunch test prep course  \
# 0    female      group B   bachelor's degree      standard             none
# 1    female      group C        some college      standard        completed
# 2    female      group B     master's degree      standard             none
# 3      male      group A  associate's degree  free/reduced             none
# 4      male      group C        some college      standard             none
# ..      ...          ...                 ...           ...              ...
# 995  female      group E     master's degree      standard        completed
# 996    male      group C         high school  free/reduced             none
# 997  female      group C         high school  free/reduced        completed
# 998  female      group D        some college      standard        completed
# 999  female      group D        some college  free/reduced             none
#
#      math score  reading score  writing score
# ...

# %%
# Filter data based on the score 
score_df = student_df.filter(like="score" )
score_df.head(10)
# Out:
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75
# 5          71             83             78
# 6          88             95             92
# 7          40             43             39
# 8          64             64             67
# 9          38             60             50

# %%
#check the data type of the Dataframe 
student_df.dtypes
# Out:
# gender              object
# income level        object
# parental edu        object
# lunch               object
# test prep course    object
# math score           int64
# reading score        int64
# writing score        int64
# dtype: object

# %%
# let work on parental Education 
parental_edu = student_df['parental edu']
parental_edu.head()
# Out:
# 0     bachelor's degree
# 1          some college
# 2       master's degree
# 3    associate's degree
# 4          some college
# Name: parental edu, dtype: object

# %%
# Get a value count for categorical columns 
student_df['parental edu'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental edu, dtype: int64

# %%
student_df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# For numerical data, get math and stat info 
student_df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
import numpy as np

# %%
from numpy.lib.function_base import average

# %%
median_math_score = average(student_df['math score'])
print("median_math_score = ",median_math_score)
# Out:
# median_math_score =  66.089

# %%
# print row the interval that you want 
parental_edu [901:911]
# Out:
# 901      master's degree
# 902          high school
# 903    bachelor's degree
# 904     some high school
# 905         some college
# 906          high school
# 907         some college
# 908    bachelor's degree
# 909    bachelor's degree
# 910    bachelor's degree
# Name: parental edu, dtype: object

# %%
# sort_value() method 

by_math_score_df = student_df.sort_values(by=['math score'], ascending=False)
by_math_score_df
# Out:
#      gender income level        parental edu         lunch test prep course  \
# 962  female      group E  associate's degree      standard             none
# 625    male      group D        some college      standard        completed
# 458  female      group E   bachelor's degree      standard             none
# 623    male      group A        some college      standard        completed
# 451  female      group E        some college      standard             none
# ..      ...          ...                 ...           ...              ...
# 145  female      group C        some college  free/reduced             none
# 787  female      group B        some college      standard             none
# 17   female      group B    some high school  free/reduced             none
# 980  female      group B         high school  free/reduced             none
# 59   female      group C    some high school  free/reduced             none
#
#      math score  reading score  writing score
# ...

# %%
# Sorted the reslut based on the reading score
by_reading_score = student_df.sort_values(by=['reading score'], ascending=False)
by_reading_score
# Out:
#      gender income level        parental edu         lunch test prep course  \
# 546  female      group A    some high school      standard        completed
# 970  female      group D   bachelor's degree      standard             none
# 149    male      group E  associate's degree  free/reduced        completed
# 566  female      group E   bachelor's degree  free/reduced        completed
# 712  female      group D        some college      standard             none
# ..      ...          ...                 ...           ...              ...
# 76     male      group E    some high school      standard             none
# 980  female      group B         high school  free/reduced             none
# 596    male      group B         high school  free/reduced             none
# 327    male      group A        some college  free/reduced             none
# 59   female      group C    some high school  free/reduced             none
#
#      math score  reading score  writing score
# ...

# %%
A_by_math_score_df = by_math_score_df[by_math_score_df['math score'] >= 90 ]
A_by_math_score_df
# Out:
#      gender income level        parental edu         lunch test prep course  \
# 962  female      group E  associate's degree      standard             none
# 625    male      group D        some college      standard        completed
# 458  female      group E   bachelor's degree      standard             none
# 623    male      group A        some college      standard        completed
# 451  female      group E        some college      standard             none
# 149    male      group E  associate's degree  free/reduced        completed
# 916    male      group E   bachelor's degree      standard        completed
# 263  female      group E         high school      standard             none
# 306    male      group E        some college      standard        completed
# 114  female      group E   bachelor's degree      standard        completed
# 104    male      group C        some college      standard        completed
# ...

# %%
# How many of them are A 
A_by_math_score_df.count()
# Out:
# gender              58
# income level        58
# parental edu        58
# lunch               58
# test prep course    58
# math score          58
# reading score       58
# writing score       58
# dtype: int64

# %%
# add a column 
student_df["attendance"] = 100
student_df
# Out:
#      gender income level        parental edu         lunch test prep course  \
# 0    female      group B   bachelor's degree      standard             none
# 1    female      group C        some college      standard        completed
# 2    female      group B     master's degree      standard             none
# 3      male      group A  associate's degree  free/reduced             none
# 4      male      group C        some college      standard             none
# ..      ...          ...                 ...           ...              ...
# 995  female      group E     master's degree      standard        completed
# 996    male      group C         high school  free/reduced             none
# 997  female      group C         high school  free/reduced        completed
# 998  female      group D        some college      standard        completed
# 999  female      group D        some college  free/reduced             none
#
# ...

# %%
# create a new column to indicate a student's passing status (passing/failing)
student_df['academic status'] = np.where(
    (student_df['math score'] +
     student_df['reading score'] +
     student_df['writing score'])/3.0 >=60,
                                         "passed",
                                         "failed")
student_df
# Out:
#      gender income level        parental edu         lunch test prep course  \
# 0    female      group B   bachelor's degree      standard             none
# 1    female      group C        some college      standard        completed
# 2    female      group B     master's degree      standard             none
# 3      male      group A  associate's degree  free/reduced             none
# 4      male      group C        some college      standard             none
# ..      ...          ...                 ...           ...              ...
# 995  female      group E     master's degree      standard        completed
# 996    male      group C         high school  free/reduced             none
# 997  female      group C         high school  free/reduced        completed
# 998  female      group D        some college      standard        completed
# 999  female      group D        some college  free/reduced             none
#
# ...
