# %% [markdown]
# <a href="https://colab.research.google.com/github/habtamuadargaso/Python-for-Data-Science-/blob/main/pandas_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **# Purpose**
#
# The purpose of the assignment is to have hand-on experience with using pandas API for rudimentary analysis of the imported data.

# %% [markdown]
# # 1
# ```
# #. Write a Python program to create a pandas DataFrame that represents your scores on all previous assignments. Please make sure to clearly label your rows and columns.
# For the following problems, read in this csv data file:
# ```
#
#
#
#
# `[cvs data link](https://www.shadowbounce.com/data/MusicArtists_100K.csv)`

# %%
import pandas as pd
import numpy as np

# %%
url = "https://www.shadowbounce.com/data/MusicArtists_100K.csv"

# %%
score_df = pd.read_csv(url)

# %%
#2 See the first and last 10 entries.
score_df.head(10)
# Out:
#    Unnamed: 0                                  mbid              artist_mb  \
# 0           0  cc197bad-dc9c-440d-a5b5-d52ba2e14234               Coldplay
# 1           1  a74b1b7f-71a5-4011-9441-d0b5e4122711              Radiohead
# 2           2  8bfac288-ccc5-448d-9573-c33ea2aa5c30  Red Hot Chili Peppers
# 3           3  73e5e69d-3554-40d8-8516-00cb38737a1c                Rihanna
# 4           4  b95ce3ff-3d05-4e87-9e01-c97b66af13d4                 Eminem
# 5           5  95e1ead9-4d31-4808-a7ac-32c3614c116b            The Killers
# 6           6  164f0d73-1234-4e2c-8743-d77bf2191051             Kanye West
# 7           7  5b11f4ce-a62d-471e-81fc-a69a8278c7da                Nirvana
# 8           8  9c9f1380-2516-4fc9-a3e6-f9f61941d090                   Muse
# 9           9  0383dadf-2a4e-4d10-a46a-e9e041da8eb3                  Queen
#
#            artist_lastfm      country_mb           country_lastfm  \
# 0               Coldplay  United Kingdom           United Kingdom
# ...

# %%
#.2 See the first and last 10 entries.

score_df.tail(10)
# Out:
#        Unnamed: 0                                  mbid           artist_mb  \
# 89795       99990  52afd739-8122-4a32-8b76-6c7113f26dd2       Wrecking Crew
# 89796       99991  039d6fdc-edcb-4c00-b62b-223e8dd520df                 CAS
# 89797       99992  d75e7c57-b954-40f3-bde7-6834aecc86c7  Dashboard Prophets
# 89798       99993  fc41eb43-7b5b-40a3-8d68-dd5dbd6741db        Gabe Gurnsey
# 89799       99994  95c659fd-57e2-4b7d-a81b-c7f19f665b90      Jonne Valtonen
# 89800       99995  a7d745ba-9df2-48b1-9d54-1d231b5356aa               Karim
# 89801       99996  1d4df834-f664-4891-9c8b-7d152298f2f0              LoREiN
# 89802       99997  195ac281-18f8-409b-a86b-c23d0474ec73        Robyn Master
# 89803       99998  e70ee8a7-0f52-4998-bc02-3c143f22cb88        The Breakers
# 89804       99999  21d3f8f8-a96b-41ab-97c6-15e6217223bd        The Breakers
#
#             artist_lastfm      country_mb            country_lastfm  \
# ...

# %%
# 3Q.  Get and display the number of records and columns.
score_df.shape
# Out:
# (89805, 11)

# %%
# 3Q. Get and display the number of records and columns.


score_df.columns
# Out:
# Index(['Unnamed: 0', 'mbid', 'artist_mb', 'artist_lastfm', 'country_mb',
#        'country_lastfm', 'tags_mb', 'tags_lastfm', 'listeners_lastfm',
#        'scrobbles_lastfm', 'ambiguous_artist'],
#       dtype='object')

# %%
#4. Display all the column names and DataFrame indices.

score_df.index
# Out:
# RangeIndex(start=0, stop=89805, step=1)

# %%
# 5 Display data types of all columns.
score_df.dtypes
# Out:
# Unnamed: 0           int64
# mbid                object
# artist_mb           object
# artist_lastfm       object
# country_mb          object
# country_lastfm      object
# tags_mb             object
# tags_lastfm         object
# listeners_lastfm     int64
# scrobbles_lastfm     int64
# ambiguous_artist      bool
# dtype: object

# %%
# 6. Display how many different artists are there and what is the most frequent artist in the dataset.
artist_df = score_df.artist_lastfm.unique()
len(artist_df)
# Out:
# 73450

# %%
# 6. Display how many different artists are there and what is the most frequent artist in the dataset.
score_df['artist_lastfm'].value_counts()
# Out:
# Karma                  26
# Trinity                24
# Angel                  23
# Nemesis                23
# Eden                   23
#                        ..
# The Godfathers          1
# Eyeopener               1
# Lovemongers             1
# Sator                   1
# Wreck and Reference     1
# Name: artist_lastfm, Length: 73449, dtype: int64

# %%
# 7. Display information about categorical columns and summarize their properties
score_df['country_mb'].value_counts()
# Out:
# United States     22088
# United Kingdom     9321
# Germany            4393
# France             2705
# Japan              2357
#                   ...
# Grenada               1
# Montserrat            1
# Kuwait                1
# Burkina Faso          1
# Turkmenistan          1
# Name: country_mb, Length: 181, dtype: int64

# %%
# 8. Display information about numerical columns and summarize their properties.
score_df['listeners_lastfm'].value_counts()
# Out:
# 8799     30
# 63179    26
# 5944     23
# 44673    23
# 5405     22
#          ..
# 67072     1
# 67079     1
# 67095     1
# 67117     1
# 39870     1
# Name: listeners_lastfm, Length: 38615, dtype: int64

# %%
#9. 9. Identify all the columns with missing entries. 
#For each column, display the number of entries missing.
score_df.isna()
# Out:
#        Unnamed: 0   mbid  artist_mb  artist_lastfm  country_mb  \
# 0           False  False      False          False       False
# 1           False  False      False          False       False
# 2           False  False      False          False       False
# 3           False  False      False          False       False
# 4           False  False      False          False       False
# ...           ...    ...        ...            ...         ...
# 89800       False  False      False          False       False
# 89801       False  False      False          False       False
# 89802       False  False      False          False        True
# 89803       False  False      False          False        True
# 89804       False  False      False          False       False
#
#        country_lastfm  tags_mb  tags_lastfm  listeners_lastfm  \
# 0               False    False        False             False
# 1               False    False        False             False
# ...

# %%
#9. Identify all the columns with missing entries. 
# For each column, display the number of entries missing.
score_df.isna().sum()
# Out:
# Unnamed: 0              0
# mbid                    0
# artist_mb               3
# artist_lastfm           4
# country_mb          23241
# country_lastfm      23309
# tags_mb             62257
# tags_lastfm          7674
# listeners_lastfm        0
# scrobbles_lastfm        0
# ambiguous_artist        0
# dtype: int64

# %%
# 11. Add a new column to the DataFrame called 'is_USA_based. For each artist record, add a column with either 'Yes' or 'No' as its contents, based on their country of origin.
score_df['is_USA_based'] = ""
score_df.head()
# Out:
#    Unnamed: 0                                  mbid              artist_mb  \
# 0           0  cc197bad-dc9c-440d-a5b5-d52ba2e14234               Coldplay
# 1           1  a74b1b7f-71a5-4011-9441-d0b5e4122711              Radiohead
# 2           2  8bfac288-ccc5-448d-9573-c33ea2aa5c30  Red Hot Chili Peppers
# 3           3  73e5e69d-3554-40d8-8516-00cb38737a1c                Rihanna
# 4           4  b95ce3ff-3d05-4e87-9e01-c97b66af13d4                 Eminem
#
#            artist_lastfm      country_mb           country_lastfm  \
# 0               Coldplay  United Kingdom           United Kingdom
# 1              Radiohead  United Kingdom           United Kingdom
# 2  Red Hot Chili Peppers   United States            United States
# 3                Rihanna   United States  Barbados; United States
# 4                 Eminem   United States            United States
#
#                                              tags_mb  \
# 0  rock; pop; alternative rock; british; uk; brit...
# ...

# %%
#10. Extract records for all artists whose names start with a letter 'b'.

score_df[score_df.artist_lastfm.str[0] == 'b']
# Out:
#        Unnamed: 0                                  mbid             artist_mb  \
# 40             40  0743b15a-3c32-48c8-ad58-cb325350befa             blink‐182
# 1691         1691  aafa70a4-2f06-4975-935e-b283fc87de7e          Blessthefall
# 5266         5266  edf81f9b-d3f0-4d57-9636-d08e851b1640                 Bazzi
# 10471       10471  35e991b9-abf7-41dc-ab0e-0ca947463808              bob hund
# 12814       12814  15c26c0c-23ac-4803-aea5-01d84e49541e           Black Coast
# 13680       13680  512171a4-d41a-4df6-838d-de0a47aea068             Boy Pablo
# 15281       15281  1ed1ac55-2147-4fc3-a0b6-ff6721d25385              BluntOne
# 16371       16371  ca1dcba2-792c-4550-abf2-7b45396e81ca                   bôa
# 19067       19067  375b0e8d-bff2-4ce0-a787-762a2878ac06               Berhana
# 20115       20115  03153d64-813d-4ec0-ae1d-0df3522c0be7              Banoffee
# 29729       29729  86368c6a-5138-4922-bd5b-809a528ffe55             Ben Platt
# ...

# %%
#11. Add a new column to the DataFrame called 'is_USA_based. For each artist record, 
# add a column with either 'Yes' or 'No' as its contents, based on their country of origin.
score_df['is_USA_based'] = np.where(
                      (score_df['country_mb'] == "United States"),
                       "Yes",
                       "No"
)
score_df
# Out:
#        Unnamed: 0                                  mbid  \
# 0               0  cc197bad-dc9c-440d-a5b5-d52ba2e14234
# 1               1  a74b1b7f-71a5-4011-9441-d0b5e4122711
# 2               2  8bfac288-ccc5-448d-9573-c33ea2aa5c30
# 3               3  73e5e69d-3554-40d8-8516-00cb38737a1c
# 4               4  b95ce3ff-3d05-4e87-9e01-c97b66af13d4
# ...           ...                                   ...
# 89800       99995  a7d745ba-9df2-48b1-9d54-1d231b5356aa
# 89801       99996  1d4df834-f664-4891-9c8b-7d152298f2f0
# 89802       99997  195ac281-18f8-409b-a86b-c23d0474ec73
# 89803       99998  e70ee8a7-0f52-4998-bc02-3c143f22cb88
# 89804       99999  21d3f8f8-a96b-41ab-97c6-15e6217223bd
#
#                    artist_mb          artist_lastfm      country_mb  \
# 0                   Coldplay               Coldplay  United Kingdom
# 1                  Radiohead              Radiohead  United Kingdom
# 2      Red Hot Chili Peppers  Red Hot Chili Peppers   United States
# ...
