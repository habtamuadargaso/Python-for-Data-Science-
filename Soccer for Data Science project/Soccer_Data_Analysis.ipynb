# %% [markdown]
# <a href="https://colab.research.google.com/github/habtamuadargaso/Python-for-Data-Science-/blob/main/Soccer_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2018-19 English Premier League: An explorartory Data Analysis

# %%
# This dataset contains data of every game from the 2018-2019 season in the english premier League
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib as plt

# %%
# Loading the dataset into a dataframe
soccer_df = pd.read_csv('/2018-2019.csv')

# Printing the number of rows and column 
print("Number of row and column", soccer_df.shape)

soccer_df
# Out:
# Number of row and column (380, 23)
#     Div     Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  10/8/18    Man United       Leicester     2     1   H     1     0
# 1    E0  11/8/18   Bournemouth         Cardiff     2     0   H     1     0
# 2    E0  11/8/18        Fulham  Crystal Palace     0     2   A     0     1
# 3    E0  11/8/18  Huddersfield         Chelsea     0     3   A     0     2
# 4    E0  11/8/18     Newcastle       Tottenham     1     2   A     1     2
# ..   ..      ...           ...             ...   ...   ...  ..   ...   ...
# 375  E0  12/5/19     Liverpool          Wolves     2     0   H     1     0
# 376  E0  12/5/19    Man United         Cardiff     0     2   A     0     1
# 377  E0  12/5/19   Southampton    Huddersfield     1     1   D     1     0
# 378  E0  12/5/19     Tottenham         Everton     2     2   D     1     0
# 379  E0  12/5/19       Watford        West Ham     1     4   A     0     2
#
#     HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     H  ...   6    4  11   8   2   5   2   1   0   0
# 1     H  ...   4    1  11   9   7   4   1   1   0   0
# 2     A  ...   6    9   9  11   5   5   1   2   0   0
# 3     A  ...   1    4   9   8   2   5   2   1   0   0
# 4     A  ...   2    5  11  12   3   5   2   2   0   0
# ..   ..  ...  ..  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375   H  ...   5    2   3  11   4   1   0   2   0   0
# 376   A  ...  10    4   9   6  11   2   3   3   0   0
# 377   H  ...   3    3   8   6   4   3   0   1   0   0
# 378   H  ...   3    9  10  13   7   4   0   2   0   0
# 379   A  ...   8    9  10  10   7   2   1   0   1   0
#
# [380 rows x 23 columns]

# %% [markdown]
# # Understanding Columns and values

# %%
soccer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       380 non-null    object
#  1   Date      380 non-null    object
#  2   HomeTeam  380 non-null    object
#  3   AwayTeam  380 non-null    object
#  4   FTHG      380 non-null    int64
#  5   FTAG      380 non-null    int64
#  6   FTR       380 non-null    object
#  7   HTHG      380 non-null    int64
#  8   HTAG      380 non-null    int64
#  9   HTR       380 non-null    object
#  10  Referee   380 non-null    object
#  11  HS        380 non-null    int64
#  12  AS        380 non-null    int64
#  13  HST       380 non-null    int64
#  14  AST       380 non-null    int64
#  15  HF        380 non-null    int64
#  16  AF        380 non-null    int64
#  17  HC        380 non-null    int64
#  18  AC        380 non-null    int64
#  19  HY        380 non-null    int64
#  20  AY        380 non-null    int64
#  21  HR        380 non-null    int64
#  22  AR        380 non-null    int64
# dtypes: int64(16), object(7)
# memory usage: 68.4+ KB

# %%
soccer_df.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR'],
#       dtype='object')

# %%
# Check the missing value of soccer and aggregating it using the sum()
soccer_df.isna()
# Out:
#        Div   Date  HomeTeam  AwayTeam   FTHG   FTAG    FTR   HTHG   HTAG  \
# 0    False  False     False     False  False  False  False  False  False
# 1    False  False     False     False  False  False  False  False  False
# 2    False  False     False     False  False  False  False  False  False
# 3    False  False     False     False  False  False  False  False  False
# 4    False  False     False     False  False  False  False  False  False
# ..     ...    ...       ...       ...    ...    ...    ...    ...    ...
# 375  False  False     False     False  False  False  False  False  False
# 376  False  False     False     False  False  False  False  False  False
# 377  False  False     False     False  False  False  False  False  False
# 378  False  False     False     False  False  False  False  False  False
# 379  False  False     False     False  False  False  False  False  False
#
#        HTR  ...    HST    AST     HF     AF     HC     AC     HY     AY  \
# 0    False  ...  False  False  False  False  False  False  False  False
# 1    False  ...  False  False  False  False  False  False  False  False
# 2    False  ...  False  False  False  False  False  False  False  False
# 3    False  ...  False  False  False  False  False  False  False  False
# 4    False  ...  False  False  False  False  False  False  False  False
# ..     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 375  False  ...  False  False  False  False  False  False  False  False
# 376  False  ...  False  False  False  False  False  False  False  False
# 377  False  ...  False  False  False  False  False  False  False  False
# 378  False  ...  False  False  False  False  False  False  False  False
# 379  False  ...  False  False  False  False  False  False  False  False
#
#         HR     AR
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 375  False  False
# 376  False  False
# 377  False  False
# 378  False  False
# 379  False  False
#
# [380 rows x 23 columns]

# %%
# Now, let's use the isna() function and aggregating it using sum() to get the total count of missing values.

print("The data is complete as there are no null values")
soccer_df.isna().sum()
# Out:
# The data is complete as there are no null values
# Div         0
# Date        0
# HomeTeam    0
# AwayTeam    0
# FTHG        0
# FTAG        0
# FTR         0
# HTHG        0
# HTAG        0
# HTR         0
# Referee     0
# HS          0
# AS          0
# HST         0
# AST         0
# HF          0
# AF          0
# HC          0
# AC          0
# HY          0
# AY          0
# HR          0
# AR          0
# dtype: int64

# %%
# Describe() funcation which give us helpful descriptive stats for our data
soccer_df.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.568421    1.252632    0.678947    0.573684   14.134211   11.144737
# std      1.312836    1.180031    0.860802    0.766958    5.855371    4.654002
# min      0.000000    0.000000    0.000000    0.000000    0.000000    2.000000
# 25%      1.000000    0.000000    0.000000    0.000000   10.000000    8.000000
# 50%      1.000000    1.000000    0.000000    0.000000   14.000000   11.000000
# 75%      2.000000    2.000000    1.000000    1.000000   18.000000   14.000000
# max      6.000000    6.000000    4.000000    3.000000   36.000000   25.000000
#
#               HST         AST          HF          AF          HC          AC  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     4.778947    3.928947   10.152632   10.305263    5.705263    4.552632
# std      2.677686    2.283982    3.293532    3.503707    2.971718    2.730627
# min      0.000000    0.000000    0.000000    3.000000    0.000000    0.000000
# 25%      3.000000    2.000000    8.000000    8.000000    4.000000    2.750000
# 50%      5.000000    4.000000   10.000000   10.000000    5.000000    4.000000
# 75%      6.000000    5.250000   12.000000   13.000000    8.000000    6.000000
# max     14.000000   12.000000   23.000000   21.000000   16.000000   14.000000
#
#                HY          AY          HR          AR
# count  380.000000  380.000000  380.000000  380.000000
# mean     1.526316    1.684211    0.047368    0.076316
# std      1.222844    1.209140    0.212706    0.275599
# min      0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    1.000000    0.000000    0.000000
# 50%      1.000000    2.000000    0.000000    0.000000
# 75%      2.000000    2.000000    0.000000    0.000000
# max      6.000000    5.000000    1.000000    2.000000

# %%
# print the total number of teams that participated in the season
soccer_df['HomeTeam'].unique()
# Out:
# array(['Man United', 'Bournemouth', 'Fulham', 'Huddersfield', 'Newcastle',
#        'Watford', 'Wolves', 'Arsenal', 'Liverpool', 'Southampton',
#        'Cardiff', 'Chelsea', 'Everton', 'Leicester', 'Tottenham',
#        'West Ham', 'Brighton', 'Burnley', 'Man City', 'Crystal Palace'],
#       dtype=object)

# %%
# using the value_count() funcation to print out the number of row for each unique team
# how many games does each team played 
soccer_df['HomeTeam'].value_counts(dropna=True)
# Out:
# Man United        19
# Bournemouth       19
# Man City          19
# Burnley           19
# Brighton          19
# West Ham          19
# Tottenham         19
# Leicester         19
# Everton           19
# Chelsea           19
# Cardiff           19
# Southampton       19
# Liverpool         19
# Arsenal           19
# Wolves            19
# Watford           19
# Newcastle         19
# Huddersfield      19
# Fulham            19
# Crystal Palace    19
# Name: HomeTeam, dtype: int64

# %% [markdown]
# # Data Visualizations

# %%
# Plotting a boxplot to figure out some outliers. 

soccer_df.plot(kind = 'box',figsize =(12,8))

# %% [markdown]
# - Largest distribution of data is of 'Hometeam shots'.
# - Every category has outliers. However, the largest amount of outliers for 'AC' (corners taken by the away team).
# - Also, there are significant outliers for 'HY'. This means that were matches with an oddly large amouont of yellow cards.

# %%
# Checking the Distribution 
# Let's use a histogram to further analyze one column in the df.
# Plotting the distribution of full-time home and away goals 
soccer_df.plot(kind = "hist",y = 'FTAG', title = 'Home Goals', bins = 5, alpha = 0.3)

# %%
#Away Goals
soccer_df.plot(
	kind = "hist",
    y = 'FTAG',
    bins = 5,
    alpha = 0.3,
    title = 'Away Goals'
   
)

# %% [markdown]
# - Distribution of home and away goals is similar.
# - However, the frequency of away goals seems to be higher in the 0 - 1 range.

# %%
soccer_df
# Out:
#     Div     Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  10/8/18    Man United       Leicester     2     1   H     1     0
# 1    E0  11/8/18   Bournemouth         Cardiff     2     0   H     1     0
# 2    E0  11/8/18        Fulham  Crystal Palace     0     2   A     0     1
# 3    E0  11/8/18  Huddersfield         Chelsea     0     3   A     0     2
# 4    E0  11/8/18     Newcastle       Tottenham     1     2   A     1     2
# ..   ..      ...           ...             ...   ...   ...  ..   ...   ...
# 375  E0  12/5/19     Liverpool          Wolves     2     0   H     1     0
# 376  E0  12/5/19    Man United         Cardiff     0     2   A     0     1
# 377  E0  12/5/19   Southampton    Huddersfield     1     1   D     1     0
# 378  E0  12/5/19     Tottenham         Everton     2     2   D     1     0
# 379  E0  12/5/19       Watford        West Ham     1     4   A     0     2
#
#     HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     H  ...   6    4  11   8   2   5   2   1   0   0
# 1     H  ...   4    1  11   9   7   4   1   1   0   0
# 2     A  ...   6    9   9  11   5   5   1   2   0   0
# 3     A  ...   1    4   9   8   2   5   2   1   0   0
# 4     A  ...   2    5  11  12   3   5   2   2   0   0
# ..   ..  ...  ..  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375   H  ...   5    2   3  11   4   1   0   2   0   0
# 376   A  ...  10    4   9   6  11   2   3   3   0   0
# 377   H  ...   3    3   8   6   4   3   0   1   0   0
# 378   H  ...   3    9  10  13   7   4   0   2   0   0
# 379   A  ...   8    9  10  10   7   2   1   0   1   0
#
# [380 rows x 23 columns]

# %%
soccer_df_bar = soccer_df.groupby(["HomeTeam"])["FTHG"].mean()
soccer_df_bar
# Out:
# HomeTeam
# Arsenal           2.210526
# Bournemouth       1.578947
# Brighton          1.000000
# Burnley           1.263158
# Cardiff           1.105263
# Chelsea           2.052632
# Crystal Palace    1.000000
# Everton           1.578947
# Fulham            1.157895
# Huddersfield      0.526316
# Leicester         1.263158
# Liverpool         2.894737
# Man City          3.000000
# Man United        1.736842
# Newcastle         1.263158
# Southampton       1.421053
# Tottenham         1.789474
# Watford           1.368421
# West Ham          1.684211
# Wolves            1.473684
# Name: FTHG, dtype: float64

# %%
soccer_df_bar.plot(kind = 'bar',
                   ylabel = 'Home goals scored',
                   xlabel = 'Home Team',
                   title = "Average Home Goals Scored by Home Teams",#figsize = (15,5)
)

# %% [markdown]
# - Liverpool & Manchester City have the highest average number of home goals scored as home teams.

# %%
# What about the most amount away goals scored by away teams?
soccer_df_mean = soccer_df.groupby(["AwayTeam"])['FTAG'].mean()
soccer_df_mean
# Out:
# AwayTeam
# Arsenal           1.631579
# Bournemouth       1.368421
# Brighton          0.842105
# Burnley           1.105263
# Cardiff           0.684211
# Chelsea           1.263158
# Crystal Palace    1.684211
# Everton           1.263158
# Fulham            0.631579
# Huddersfield      0.631579
# Leicester         1.421053
# Liverpool         1.789474
# Man City          2.000000
# Man United        1.684211
# Newcastle         0.947368
# Southampton       0.947368
# Tottenham         1.736842
# Watford           1.368421
# West Ham          1.052632
# Wolves            1.000000
# Name: FTAG, dtype: float64

# %%
# What about the most amount away goals scored by away teams?

soccer_df_mean.plot(kind = 'bar', ylabel = 'Away goal scored', xlabel = 'Away goals scored', figsize=(15,5))

# %% [markdown]
# - Looks like Manchester City had the highest average number of away goals scored as away team as well.
# - Followed by Liverpool, Man united, Tottenham and Crystal Palace

# %%
# Convert any data and/or time column to datetime format
soccer_df['Date'] = pd.to_datetime(soccer_df['Date'])

# %%
df_dates = soccer_df['Date'].groupby([soccer_df['Date'].dt.dayofweek]).count()

# %%
# As expected, most of the matches happened on the weekend. 
df_dates.plot(kind = "line", 
              ylabel = "Count of matches",
              xlabel = "Days of the Week",
              title = "Number of Matches vs. Days of Week",
              figsize = (15,5)
              )

# %% [markdown]
# # Exploring Relationships between variables

# %%
soccer_df.plot(kind = "scatter",
               x = "HF", # Fouls made by hometeam 
               y = "HY",# yellow card bookings for Home Team,
               xlabel = "Fouls made by hometeam",
               ylabel = "Number of yellow cards received by home team",
               title = "Relationship b/w Foluls Made and Yellow cards Issued",
               figsize =(15,5))

# %%
# Filtering the main dataframe
df_2 = soccer_df.filter(items = ["FTHG","FTAG","HTS","HS","AS","HC","AC"])
df_2.head()
# Out:
#    FTHG  FTAG  HS  AS  HC  AC
# 0     2     1   8  13   2   5
# 1     2     0  12  10   7   4
# 2     0     2  15  10   5   5
# 3     0     3   6  13   2   5
# 4     1     2  15  15   3   5

# %%
# Generate and print pairwise correlation of columns
cm = df_2.corr()
# print(cm)

# Plot the correlation matrix nicely using Seaborn
figsize = (20,9)
sns.heatmap(cm, annot=True, )

# %% [markdown]
# As expected, positive correlations exist between the goals scored by home team and the number of shaots they took.
# Moreover, there is a positive correlation between goals scored and number of corners taken. In other words, the team, who gets more corners increases its chances of scoring a goal.
# The same is true for the away team as well.
